# %%
import pandas as pd
# Read the CSV files
results_df = pd.read_csv("results.csv")

results_df
# Out:
#      population_size  generations  sample_ratio  similarity_penalty  elitism  \
# 0                 50           50           0.4                0.25       10
# 1                 50           50           0.4                0.25       10
# 2                 30           40           0.4                0.25        5
# 3                 30           40           0.3                0.25        5
# 4                 30           40           0.3                0.25        5
# ..               ...          ...           ...                 ...      ...
# 138               20           40           0.4                0.05        2
# 139               20           40           0.4                0.05        2
# 140               20          150           0.3                0.05        2
# 141               20          150           0.3                0.05        2
# 142               20          150           0.3                0.25        5
#
# ...

# %%
sorted_df = results_df.sort_values(by="best_fitness", ascending=True)
sorted_df
# Out:
#      population_size  generations  sample_ratio  similarity_penalty  elitism  \
# 36               100          500           0.6                0.25        5
# 29               100          500           0.6                0.25        5
# 37               100          500           0.6                0.10        5
# 30               100          500           0.6                0.10        5
# 25                25          500           0.6                0.25        2
# ..               ...          ...           ...                 ...      ...
# 91                20           40           0.4                0.05        2
# 1                 50           50           0.4                0.25       10
# 131               20           40           0.4                0.05        2
# 22                25           30           0.6                0.25        2
# 61                20           40           0.4                0.80        5
#
# ...
